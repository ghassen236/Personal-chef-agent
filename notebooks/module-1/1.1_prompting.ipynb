# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# from langchain.agents import create_agent
# from langchain.messages import HumanMessage

# agent = create_agent(model="gpt-5-nano")

# question = HumanMessage(content="What's the capital of the moon?")

# response = agent.invoke(
#     {"messages": [question]}
# )

# print(response['messages'][1].content)

from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain_groq import ChatGroq

# Create the model
model = ChatGroq(model="llama-3.3-70b-versatile")

# Pass the MODEL OBJECT to create_agent
agent = create_agent(model=model)  # ✅ CORRECT

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The Moon does not have a capital city. The Moon is a natural satellite that orbits the Earth, and it does not have a government or permanent human settlements. While there have been several manned missions to the Moon in the past, no human has ever established a permanent residence there.
#
# However, there are some interesting geographical features on the Moon, such as the Sea of Tranquility (Mare Tranquillitatis), where the first humans, Neil Armstrong and Buzz Aldrin, landed during the Apollo 11 mission in 1969. But there is no capital city or centralized hub of activity on the Moon.
#
# If you have any further questions or if there's anything else I can help you with, feel free to ask!
# Failed to multipart ingest runs: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# ...

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# I'm happy to create a capital city for the moon. Let's call it... Lunaria!
#
# Lunaria is a thriving, self-sustaining metropolis that serves as the capital of the lunar government. Located in the heart of the moon's near side, Lunaria is nestled within a massive, naturally formed crater known as the "Sea of Tranquility Basin." The city's unique architecture is a blend of futuristic design and lunar-inspired aesthetics, with towering domes, sweeping arches, and intricate networks of transparent tubes and tunnels.
#
# ...

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The capital of the moon is Lunaria City, also known as New Tranquility. It's a bustling metropolis built into the cratered surface, with towering domes that enclose a vibrant, self-sustaining ecosystem. Lunaria City is the seat of the Lunar Union government and a hub of interplanetary commerce, innovation, and culture.
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Lunaria
#
# Location: Southern crater of the Moon's near side, overlooking the vast, dark expanse of the South Pole-Aitken basin
#
# Vibe: Futuristic Oasis
#
# Economy: The main industries driving Lunaria's economy are Helium-3 mining, Lunar Regolith processing, and Space Tourism, with a growing sector of Advanced Manufacturing and Zero-Gravity Research.
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model= model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Lunar Haven', location='The Moon', vibe='futuristic', economy='space-based')
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
response["structured_response"].name
# Out:
# 'Lunar Haven'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunar Haven is a city located at The Moon

# %% [markdown]
# ##### These methods help us keep an agent focused on its task, providing shorter but higher quality answers

# %% [markdown]
# ### To recap, we've learned how to :
# #### initialize the model,
# #### add it to our agent,
# #### invoke it with questions
# #### and even control the agents behaviour using system prompts, structured output schema.

# %% [markdown]
# ## But what makes an agent different to the chat model that we just built it on ?
#
# ## That is its access to tools , which we'll be covering in the next notebooks !
