# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os

# Get your key from environment
google_key = os.getenv("GOOGLE_API_KEY")
print(f"Key exists: {bool(google_key)}")
# Create the model
model = ChatGoogleGenerativeAI(
    model="models/gemini-2.5-flash", 
    google_api_key=google_key
)
# Out:
# Key exists: True

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    #model="gpt-5-nano",
    model= model,
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some leftover chicken and rice. What can I make?")]},
    config
)

print(response['messages'][-1].content)
# Out:
# Failed to multipart ingest runs: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# [{'type': 'text', 'text': "You can make a delicious **Chicken Fried Rice** with your leftover chicken and rice! It's a quick and easy dish that many people enjoy.\n\nAnother option is a **Chicken and Rice Casserole**.\n\nWould you like the recipe for Chicken Fried Rice?", 'extras': {'signature': '...'}}]
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='75c1b291-0019-4a36-a902-a477bb1736dd'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'web_search', 'arguments': '{"query": "recipes with leftover chicken and rice"}'}, '__gemini_function_call_thought_signatures__': {'6f9fc598-d55e-48a5-98f4-9a5200471169': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c41d8-e291-70a0-9a20-ec6b81adda87-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'recipes with leftover chicken and rice'}, 'id': '6f9fc598-d55e-48a5-98f4-9a5200471169', 'type': 'tool_call'}], usage_metadata={'input_tokens': 114, 'output_tokens': 61, 'total_tokens': 175, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 41}}),
#               ToolMessage(content='{"query": "recipes with leftover chicken and rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.youtube.com/watch?v=OhI4SYVj80A", "title": "How to Make Chicken Fried Rice Like The Restaurant - YouTube", "content": "How to Make Chicken Fried Rice Like The Restaurant | Leftover Chicken | 15 min Quick & Easy Recipe\\nCaffeinated Coconut\\n3020 subscribers\\n728 likes\\n46863 views\\n26 Mar 2022\\nDo you think chicken fried rice at the Chinese takeout (or takeaway) is overpriced, but you are craving that classic and comforting Chinese dish anyways. Let me show you my chicken fried rice recipe that is not only healthy, but quick, simple and easy to make. This recipe will surely rival your favourite Chinese restaurant’s takeaway, plus it won’t set you back nearly $10. This recipe uses leftover chicken AND leftover rice, and each step is cooked with care to ensure that you become the master of your wok and of your very own chicken fried rice. \\n***************************************************************************\\nChicken Fried Rice Recipe Ingredients (2 full or 4 side servings) \\n- 1 cup of leftover chicken (can use rotisserie chicken or chicken breast or thigh meat)\\n- 2 cup of leftover white rice cooked from the day before (jasmine rice preferred) \\n- 1 small yellow onion, diced\\n- 1 clove of garlic, diced\\n- 3 sprigs of green onion (scallion) \\n- 1 cup of mixed frozen vegetables \\n- 1 Tbsp oyster sauce \\n- 2 Tbsp soy sauce (or to taste)\\n- 1 tsp sesame oil \\n- 1 large egg, beaten\\n- 1 Tbsp of neutral oil (vegetable/canola oil), do not use olive oil\\n***************************************************************************\\nPlease like and subscribe to my channel for more simple home cooking recipes to come. If you have any questions about the recipe, please comment below, and I’ll try to get back to you as soon as I can. Enjoy!\\n19 comments\\n", "score": 0.8668671, "raw_content": null}, {"url": "https://www.facebook.com/TheRecipeCritic/posts/grab-you-leftover-rice-and-chicken-toss-it-all-in-a-pan-and-boom-dinner-is-ready/1251345426337809/", "title": "Grab you leftover rice and chicken, toss it all in a pan, and boom ...", "content": "3lbs Chicken Breast 2.5C Jasmine Rice 5 bell peppers sliced (colorful!) 1 yellow onion sliced 1 can stewed tomatoes (organic no salt) Put", "score": 0.86108357, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=6ioZjlmtKv8", "title": "Leftover Chicken and Rice Recipe For Dinner - YouTube", "content": "Leftover Chicken and Rice Recipe For Dinner\\nTracy\'s Cookin’\\n14700 subscribers\\n56 likes\\n8401 views\\n6 May 2022\\nThis Easy and delicious dinner is made with leftover baked chicken and leftover rice. it\'s amazing how you can create a quick and easy Dinner Recipe using leftover food.\\n4 comments\\n", "score": 0.83225065, "raw_content": null}, {"url": "https://quickweeknightmeals.com/chicken-fried-rice/", "title": "Chicken Fried Rice - The Best Easy Dinner Recipes", "content": "Simple and delicious Chicken Fried Rice is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.", "score": 0.8296166, "raw_content": null}, {"url": "https://www.thecountrycook.net/chicken-and-rice-casserole/", "title": "Chicken and Rice Casserole - The Country Cook", "content": "Preheat oven to 350F degrees. · In a large bowl, stir together chicken, cooked rice, soup, mayonnaise, chicken stock and finely diced onion.", "score": 0.5911811, "raw_content": null}], "response_time": 0.91, "request_id": "f9b5a655-c620-425b-b7ed-63acb0c78a6c"}', name='web_search', id='f1babd85-8586-4c8e-8ede-0073e2f50c76', tool_call_id='6f9fc598-d55e-48a5-98f4-9a5200471169'),
#               AIMessage(content=[{'type': 'text', 'text': "You can make a delicious **Chicken Fried Rice** with your leftover chicken and rice! It's a quick and easy dish that many people enjoy.\n\nAnother option is a **Chicken and Rice Casserole**.\n\nWould you like the recipe for Chicken Fried Rice?", 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c41d8-ee92-7cf1-afb3-69ac058b1d74-0', usage_metadata={'input_tokens': 1196, 'output_tokens': 164, 'total_tokens': 1360, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 110}})]}

# %%
def clean_response(response):
    """Extract clean text from agent response"""
    last_msg = response['messages'][-1]
    
    if isinstance(last_msg.content, list):
        # Handle Gemini's list format
        for item in last_msg.content:
            if isinstance(item, dict) and item.get('type') == 'text':
                return item['text']
    else:
        return last_msg.content
    
    return "No text content found"

print(clean_response(response))
# Out:
# You can make a delicious **Chicken Fried Rice** with your leftover chicken and rice! It's a quick and easy dish that many people enjoy.
#
# Another option is a **Chicken and Rice Casserole**.
#
# Would you like the recipe for Chicken Fried Rice?
